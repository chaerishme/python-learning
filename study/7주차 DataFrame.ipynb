# %%
import pandas as pd

# %%
data = {
    "이름": ["송하나", "송두리"],
    "나이": [23, 7],
    "주특기": ["조련", "귀여움"],
    "최애" : ["송두리","간식"],
}
data
# Out:
# {'이름': ['송하나', '송두리'],
#  '나이': [23, 7],
#  '주특기': ['조련', '귀여움'],
#  '최애': ['송두리', '간식']}

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름  나이  주특기   최애
# 0  송하나  23   조련  송두리
# 1  송두리   7  귀여움   간식

# %%
df["취미"] = "산책"
df
# Out:
#     이름  나이  주특기   최애  취미
# 0  송하나  23   조련  송두리  산책
# 1  송두리   7  귀여움   간식  산책

# %%
out = df.loc[0:1, "이름":"최애"] 
out
# Out:
#     이름  나이  주특기   최애
# 0  송하나  23   조련  송두리
# 1  송두리   7  귀여움   간식
